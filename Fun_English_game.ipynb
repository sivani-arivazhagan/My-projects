# %%
# Name

# %%
print ("My Fun Story Generator")
# Out:
# My Fun Story Generator

# %%
# Creating variables
name = input("What is your name?")
# test
print(name)

place = input("Where are you from?")
print(place)

action = input("Tell me an verb that describes what you're doing that ends with -ing")
print(action)
# Out:
# What is your name?T
# T
# Where are you from?park
# park
# Tell me an verb that describes what you're doing that ends with -ingplaying
# playing

# %%
# f-string
print(f"One day {name} was {action} at {place}.")
# Out:
# One day T was playing at park.
